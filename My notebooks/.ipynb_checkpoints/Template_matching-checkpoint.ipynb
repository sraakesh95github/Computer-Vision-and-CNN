# %% [markdown]
# ## Template Matching

# %%
# Points
# 1. The template must be an exact subset of the bigger image
# 2.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../DATA/sammy.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img_face = cv2.imread('../DATA/sammy_face.jpg')
img_face = cv2.cvtColor(img_face, cv2.COLOR_BGR2RGB)
plt.imshow(img_face)

# %%
print(img.shape)
print(img_face.shape)
# Out:
# (1367, 1025, 3)
# (375, 486, 3)

# %% [markdown]
# #### Eval function

# %%
sum([2,3,4])
# Out:
# 9

# %%
my_string = 'sum'
my_func = eval(mystring)
my_func([2,3,4])
# Out:
# 9

# %% [markdown]
# ### 1. TM Coet

# %%
# Methods defined for template matching

# %%
# All the 6 methods for comparison in a list
# Note how we are using strings, later on we'll use the eval() function to convert to function
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for i in methods:
    # Create a copy of the image
    img_cpy = img.copy()
    img_face_cpy = img_face.copy()
    
    method = eval(i)
    
    # Template matching
    res = cv2.matchTemplate(img_cpy, img_face_cpy, method)
    
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    if(method in cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED):
        top_left = min_loc
    else:
        top_left = max_loc
        
    height, width, channels = img_face.shape
    
    bottom_right = (top_left[0] + width, top_left[1] + height)
    
    cv2.rectangle(img_cpy, top_left, bottom_right, color = (0 , 255, 0), thickness = 5)
    
    # Plot and display
    plt.subplot(121)
    plt.imshow(res)
    plt.title("Heatmap of template matching")
    
    plt.subplot(122)
    plt.imshow(img_cpy)
    plt.title("Detection of template")
    
    plt.supttle(m)
    
    plt.show()
    
    print('\n')
    print('\n')
# Out:
#   File "<ipython-input-22-4db6eb79f687>", line 22
#     cv2.rectangle(img_cpy, top_left, bottom_right, color = (0  255, 0), thickness = 5)
#                                                                  ^
# SyntaxError: invalid syntax

# %%
my_method = eval('cv2.TM_CCOEFF')
res = cv2.matchTemplate(img, img_face, my_method)

# %%
plt.imshow(res)

# %%
# Get the values from the above heatmap
